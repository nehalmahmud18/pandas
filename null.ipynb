# %%
import pandas as pd
df = pd.read_csv(r'/Users/richboy/Downloads/Class_Exam_Marks.csv')
df
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_35897/1125109097.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#           Name  Physics  Chemistry  Math  English
# 0   Student_01      NaN       99.0  91.0     55.0
# 1   Student_02     91.0       99.0  52.0     65.0
# 2   Student_03     68.0       99.0  80.0     87.0
# 3   Student_04     54.0       84.0  42.0     96.0
# 4   Student_05     82.0       80.0  78.0     91.0
# 5   Student_06     47.0       68.0  45.0     99.0
# 6   Student_07    100.0       54.0  47.0     88.0
# 7   Student_08     60.0        NaN  66.0     41.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Physics      5
# Chemistry    5
# Math         5
# English      5
# dtype: int64

# %%
b= df.fillna(0)
b
# Out:
#           Name  Physics  Chemistry  Math  English
# 0   Student_01      0.0       99.0  91.0     55.0
# 1   Student_02     91.0       99.0  52.0     65.0
# 2   Student_03     68.0       99.0  80.0     87.0
# 3   Student_04     54.0       84.0  42.0     96.0
# 4   Student_05     82.0       80.0  78.0     91.0
# 5   Student_06     47.0       68.0  45.0     99.0
# 6   Student_07    100.0       54.0  47.0     88.0
# 7   Student_08     60.0        0.0  66.0     41.0
# 8   Student_09     78.0       40.0  48.0     40.0
# 9   Student_10     97.0       64.0  76.0      0.0
# 10  Student_11     58.0       46.0  72.0     51.0
# 11  Student_12     62.0       48.0   0.0     44.0
# 12  Student_13      0.0       63.0   0.0      0.0
# 13  Student_14     50.0       40.0  83.0     71.0
# 14  Student_15     63.0       83.0  63.0     98.0
# 15  Student_16     92.0       47.0  54.0     94.0
# 16  Student_17     75.0       63.0  98.0     48.0
# 17  Student_18     79.0       50.0  93.0     80.0
# ...

# %%
c = df.fillna({'Physics':'none', 'Chemistry':'34','Math':'45'})
c
# Out:
#           Name Physics Chemistry  Math  English
# 0   Student_01    none      99.0  91.0     55.0
# 1   Student_02    91.0      99.0  52.0     65.0
# 2   Student_03    68.0      99.0  80.0     87.0
# 3   Student_04    54.0      84.0  42.0     96.0
# 4   Student_05    82.0      80.0  78.0     91.0
# 5   Student_06    47.0      68.0  45.0     99.0
# 6   Student_07   100.0      54.0  47.0     88.0
# 7   Student_08    60.0        34  66.0     41.0
# 8   Student_09    78.0      40.0  48.0     40.0
# 9   Student_10    97.0      64.0  76.0      NaN
# 10  Student_11    58.0      46.0  72.0     51.0
# 11  Student_12    62.0      48.0    45     44.0
# 12  Student_13    none      63.0    45      NaN
# 13  Student_14    50.0      40.0  83.0     71.0
# 14  Student_15    63.0      83.0  63.0     98.0
# 15  Student_16    92.0      47.0  54.0     94.0
# 16  Student_17    75.0      63.0  98.0     48.0
# 17  Student_18    79.0      50.0  93.0     80.0
# 18  Student_19    63.0      90.0  71.0     74.0
# ...

# %%
d = df.fillna(method='ffill')
d
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_35897/1988875573.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d = df.fillna(method='ffill')
#           Name  Physics  Chemistry  Math  English
# 0   Student_01      NaN       99.0  91.0     55.0
# 1   Student_02     91.0       99.0  52.0     65.0
# 2   Student_03     68.0       99.0  80.0     87.0
# 3   Student_04     54.0       84.0  42.0     96.0
# 4   Student_05     82.0       80.0  78.0     91.0
# 5   Student_06     47.0       68.0  45.0     99.0
# 6   Student_07    100.0       54.0  47.0     88.0
# 7   Student_08     60.0       54.0  66.0     41.0
# 8   Student_09     78.0       40.0  48.0     40.0
# 9   Student_10     97.0       64.0  76.0     40.0
# 10  Student_11     58.0       46.0  72.0     51.0
# 11  Student_12     62.0       48.0  72.0     44.0
# 12  Student_13     62.0       63.0  72.0     44.0
# ...

# %%
d = df.fillna(method='ffill', axis= 1)
d
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_35897/3158928294.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d = df.fillna(method='ffill', axis= 1)
#           Name     Physics Chemistry  Math English
# 0   Student_01  Student_01      99.0  91.0    55.0
# 1   Student_02        91.0      99.0  52.0    65.0
# 2   Student_03        68.0      99.0  80.0    87.0
# 3   Student_04        54.0      84.0  42.0    96.0
# 4   Student_05        82.0      80.0  78.0    91.0
# 5   Student_06        47.0      68.0  45.0    99.0
# 6   Student_07       100.0      54.0  47.0    88.0
# 7   Student_08        60.0      60.0  66.0    41.0
# 8   Student_09        78.0      40.0  48.0    40.0
# 9   Student_10        97.0      64.0  76.0    76.0
# 10  Student_11        58.0      46.0  72.0    51.0
# 11  Student_12        62.0      48.0  48.0    44.0
# ...

# %%
e = df['Physics'].fillna(value=df['Physics'].mean())
e
# Out:
# 0      74.022222
# 1      91.000000
# 2      68.000000
# 3      54.000000
# 4      82.000000
# 5      47.000000
# 6     100.000000
# 7      60.000000
# 8      78.000000
# 9      97.000000
# 10     58.000000
# 11     62.000000
# 12     74.022222
# 13     50.000000
# 14     63.000000
# 15     92.000000
# 16     75.000000
# 17     79.000000
# 18     63.000000
# 19     42.000000
# 20     61.000000
# 21     92.000000
# 22     41.000000
# 23     63.000000
# 24     83.000000
# 25     69.000000
# 26     77.000000
# 27     41.000000
# 28     99.000000
# 29     60.000000
# 30     72.000000
# 31     74.022222
# 32     97.000000
# 33     61.000000
# 34    100.000000
# 35     83.000000
# 36     64.000000
# 37     88.000000
# 38     66.000000
# 39     98.000000
# 40     81.000000
# 41     67.000000
# 42     99.000000
# 43     55.000000
# 44     74.022222
# 45     86.000000
# 46     90.000000
# 47     83.000000
# 48     94.000000
# 49     74.022222
# Name: Physics, dtype: float64

# %%
f = df.fillna(method='bfill')
f
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_35897/2670076046.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   f = df.fillna(method='bfill')
#           Name  Physics  Chemistry  Math  English
# 0   Student_01     91.0       99.0  91.0     55.0
# 1   Student_02     91.0       99.0  52.0     65.0
# 2   Student_03     68.0       99.0  80.0     87.0
# 3   Student_04     54.0       84.0  42.0     96.0
# 4   Student_05     82.0       80.0  78.0     91.0
# 5   Student_06     47.0       68.0  45.0     99.0
# 6   Student_07    100.0       54.0  47.0     88.0
# 7   Student_08     60.0       40.0  66.0     41.0
# 8   Student_09     78.0       40.0  48.0     40.0
# 9   Student_10     97.0       64.0  76.0     51.0
# 10  Student_11     58.0       46.0  72.0     51.0
# 11  Student_12     62.0       48.0  83.0     44.0
# 12  Student_13     50.0       63.0  83.0     71.0
# ...

# %%
g = df.fillna(method='bfill', inplace= True)
g
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_35897/1751111195.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   g = df.fillna(method='bfill', inplace= True)

# %%
g
