# %%
import pandas as pd
df = pd.read_csv(r'/Users/richboy/Downloads/Founders Meet Up - Celebrate With Light of Hope.csv')
df
# Out:
# /var/folders/s0/4z06h3kn7yd9d1wp9677tp_00000gn/T/ipykernel_30356/4227697598.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     Unnamed: 0   Founder's Meet Up - Celebrate with Light of Hope  \
# 0          NaN  Founder's meet up to celebrate Waliullah Bhuiy...
# 1          NaN                                       For contact:
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4        Sl No                                               Name
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Founder's Meet Up - Celebrate with Light of Hope',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df.shape
# Out:
# (496, 9)

# %%
df.size
# Out:
# 4464

# %%
df.head()
# Out:
#   Unnamed: 0   Founder's Meet Up - Celebrate with Light of Hope  \
# 0        NaN  Founder's meet up to celebrate Waliullah Bhuiy...
# 1        NaN                                       For contact:
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4      Sl No                                               Name
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1  Waliullah Bhuiyan, Founder, Light of Hope, 017...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                  Organization Name   Position      Email
#
#      Unnamed: 5           Unnamed: 6                      Unnamed: 7  \
# ...

# %%
df.head(10)
# Out:
#   Unnamed: 0   Founder's Meet Up - Celebrate with Light of Hope  \
# 0        NaN  Founder's meet up to celebrate Waliullah Bhuiy...
# 1        NaN                                       For contact:
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4      Sl No                                               Name
# 5          1                               A M Ishtiaque Sarwar
# 6          2                                  A.K.M FIROJ IQBAL
# 7          3                                  Abdul Gaffar Sadi
# 8          4                               Abdullah Abyad Raied
# 9          5                                 Abdullah Al Mamun
#
#                                           Unnamed: 2         Unnamed: 3  \
# 0                                                NaN                NaN
# 1  Waliullah Bhuiyan, Founder, Light of Hope, 017...                NaN
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0 Founder's Meet Up - Celebrate with Light of Hope Unnamed: 2  \
# 491        NaN                                              NaN        NaN
# 492        NaN                                              NaN        NaN
# 493        NaN                                              NaN        NaN
# 494        NaN                                              NaN        NaN
# 495        NaN                                              NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 491        NaN        NaN        NaN        NaN        NaN        NaN
# 492        NaN        NaN        NaN        NaN        NaN        NaN
# 493        NaN        NaN        NaN        NaN        NaN        NaN
# 494        NaN        NaN        NaN        NaN        NaN        NaN
# 495        NaN        NaN        NaN        NaN        NaN        NaN

# %%
df.describe()
# Out:
#        Unnamed: 0 Founder's Meet Up - Celebrate with Light of Hope  \
# count         199                                              201
# unique        199                                              199
# top         Sl No                                   Ahmed Shahriar
# freq            1                                                2
#
#           Unnamed: 2 Unnamed: 3               Unnamed: 4   Unnamed: 5  \
# count            200        199                      198          199
# unique           192         91                      196          193
# top     Banglar Math    Founder  asif@minimallimited.com  8.80173E+12
# freq               4         27                        2            2
#
#                  Unnamed: 6 Unnamed: 7 Unnamed: 8
# count                    10         34          1
# unique                   10         26          1
# top     Alternative Number        ITES          a
# freq                      1          3          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Unnamed: 0                                        199 non-null    object
#  1   Founder's Meet Up - Celebrate with Light of Hope  201 non-null    object
#  2   Unnamed: 2                                        200 non-null    object
#  3   Unnamed: 3                                        199 non-null    object
#  4   Unnamed: 4                                        198 non-null    object
#  5   Unnamed: 5                                        199 non-null    object
#  6   Unnamed: 6                                        10 non-null     object
#  7   Unnamed: 7                                        34 non-null     object
#  8   Unnamed: 8                                        1 non-null      object
# ...

# %%
df2 = pd.read_csv(r'/Users/richboy/Downloads/resturant.csv')
df2
# Out:
#           Item Name      Segment     Category Sales (BDT) YoY Sales (%)  \
# 0   Chicken Biryani  Main Course  Rice Dishes    1,20,000         8.50%
# 1       Beef Tehari  Main Course  Rice Dishes      95,000         6.10%
# 2    Chicken Burger       Snacks    Fast Food      60,000           NaN
# 3          Veg Roll       Snacks    Fast Food      32,000         2.50%
# 4   Grilled Chicken  Main Course        Grill    1,10,000        12.20%
# 5      French Fries       Snacks    Side Dish      40,500         4.00%
# 6     Chicken Pizza  Main Course    Fast Food      85,000         9.30%
# 7      Water Bottle    Beverages       Drinks      10,000         1.50%
# 8       Cold Coffee    Beverages       Drinks         NaN           NaN
# 9  Fresh Lime Juice    Beverages       Drinks      20,000         3.50%
#
#    Units Sold YoY Units (%)       Item Name.1    Segment.1   Category.1  \
# 0      2400.0         5.20%   Chicken Biryani  Main Course  Rice Dishes
# ...

# %%
df2.head()
# Out:
#          Item Name      Segment     Category Sales (BDT) YoY Sales (%)  \
# 0  Chicken Biryani  Main Course  Rice Dishes    1,20,000         8.50%
# 1      Beef Tehari  Main Course  Rice Dishes      95,000         6.10%
# 2   Chicken Burger       Snacks    Fast Food      60,000           NaN
# 3         Veg Roll       Snacks    Fast Food      32,000         2.50%
# 4  Grilled Chicken  Main Course        Grill    1,10,000        12.20%
#
#    Units Sold YoY Units (%)      Item Name.1    Segment.1   Category.1  \
# 0      2400.0         5.20%  Chicken Biryani  Main Course  Rice Dishes
# 1      1800.0         3.80%      Beef Tehari  Main Course  Rice Dishes
# 2      1400.0           NaN   Chicken Burger       Snacks    Fast Food
# 3       900.0         4.10%         Veg Roll       Snacks    Fast Food
# 4      1300.0         6.70%  Grilled Chicken  Main Course        Grill
#
#   Sales (BDT).1
# 0      1,20,000
# 1        95,000
# 2        60,000
# 3        32,000
# 4      1,10,000

# %%
df2.shape
# Out:
# (10, 11)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Name      10 non-null     object
#  1   Segment        10 non-null     object
#  2   Category       10 non-null     object
#  3   Sales (BDT)    9 non-null      object
#  4   YoY Sales (%)  8 non-null      object
#  5   Units Sold     9 non-null      float64
#  6   YoY Units (%)  8 non-null      object
#  7   Item Name.1    10 non-null     object
#  8   Segment.1      10 non-null     object
#  9   Category.1     10 non-null     object
#  10  Sales (BDT).1  9 non-null      object
# dtypes: float64(1), object(10)
# memory usage: 1012.0+ bytes

# %%
df2.describe()
# Out:
#         Units Sold
# count     9.000000
# mean   1811.111111
# std    1289.810494
# min     900.000000
# 25%    1000.000000
# 50%    1400.000000
# 75%    1800.000000
# max    5000.000000
